# %%
import pandas as pd
import quandl
import datetime
 
start = datetime.datetime(2015,1,1) 
end = datetime.date.today()


apple, amazon, google, alphabet = (quandl.get("WIKI/" + s, start_date=start, end_date=end) for s in ["AAPL", "AMZN","GOOG", "GOOGL"])
 
stocks = pd.DataFrame({"AAPL": apple["Adj. Close"],
                      "AMZN": amazon["Adj. Close"],
                      "GOOG": google["Adj. Close"],
                      "GOOGL": alphabet["Adj. Close"]}) #Alphabet Inc.
 
stocks.head()
# Out:
#                   AAPL    AMZN    GOOG   GOOGL
# Date
# 2015-01-02  103.863957  308.52  524.81  529.55
# 2015-01-05  100.937944  302.19  513.87  519.46
# 2015-01-06  100.947444  295.29  501.96  506.64
# 2015-01-07  102.362951  298.42  501.10  505.15
# 2015-01-08  106.295968  300.46  502.68  506.91

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

stocks.plot(grid = True)

# %%
stock_return = stocks.apply(lambda x: x / x[0])
stock_return.head() - 1

stock_return.plot(grid = True).axhline(y = 1, color = "black", lw = 2)
